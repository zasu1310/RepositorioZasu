# %% [markdown]
# **Una cepa de E.coli tiene una tasa de crecimiento tal que un individuo se duplica cada 30 min.**
#
#  *Calcula en cuanto tiempo esta cepa:*
#
# a) llenaria el volumen de la tierra (considerada como una esfera hueca)(a partir del r de la tierra)
#
# b) cubrir la superficie de la tierra.
#
# c) Repite el calculo para una tasa de crecimiento:
#
#   i) se duplica cada hora.
#  ii) se duplica cada 1/4 de hora.

# %% [markdown]
# *DATOS*
#
# rT= 6,371km
#
# rE= 0.5nm

# %%
import math as mt

# %% [markdown]
# **a) Volumen de la Tierra**

# %%
rT= 6371*10e3
rE= 0.5*10e-6
N= rT**3/rE**3
print(rT**3/rE**3)
# Out:
# 2.0687728224879996e+39

# %%
N= ((6.371/5)**3*10e39)
t=mt.log2(N)

# %%
t
# Out:
# 133.92589902316476

# %%
th=t/2
td=th/24
print (td)
# Out:
# 2.7901228963159324

# %% [markdown]
# **b) Superficie de la Tierra**

# %%
rT= 6371*10e3
rE= 0.5*10e-6
N= rT**2/rE**2
print(N)
# Out:
# 1.6235856399999996e+26

# %%
N= rT**2/rE**2
t= mt.log2(N)
print(t)
# Out:
# 87.06931395218493

# %%
t=mt.log2(N)
th=t/2
td=th/24
print(td)
# Out:
# 1.8139440406705194

# %% [markdown]
# **c) Tasas de cremiento**
#
# i) Tasa de crecimiento por 1 hora

# %% [markdown]
# volumen:

# %%
N= rT**3/rE**3
t= mt.log2(N)
print(t)
# Out:
# 130.6039709282774

# %%
t=mt.log2(N)
th= t
td=th/24
print(td)
# Out:
# 5.441832122011558

# %% [markdown]
# Superficie

# %%
rT= 6371*10e3
rE= 0.5*10e-6
N= rT**2/rE**2
print(N)
# Out:
# 1.6235856399999996e+26

# %%
t=mt.log2(N)
th=t 
td=th/24
print(td)
# Out:
# 3.627888081341039

# %% [markdown]
# *ii) Tasa de crecimiento por 1/4 de hora*

# %% [markdown]
# volumen

# %%
N= rT**3/rE**3
t= mt.log2(N)
print(t)
# Out:
# 130.6039709282774

# %%
t=mt.log2(N)
th=t/4
td=th/24
print(td)
# Out:
# 1.3604580305028895

# %% [markdown]
# superficie

# %%
N= rT**2/rE**2
t= mt.log2(N)
print(t)
# Out:
# 87.06931395218493

# %%
t=mt.log2(N)
th=t/4
td=th/24
print(td)
# Out:
# 0.9069720203352597
